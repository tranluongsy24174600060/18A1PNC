# %%
noi_dung_xml = """<?xml version="1.0" encoding="UTF-8"?>
<danhsach_sinhvien>
    <sinhvien ma_sv="SV001">
        <ho_ten>Nguyễn Văn An</ho_ten>
        <nam_sinh>2002</nam_sinh>
        <lop>CTK44</lop>
        <gioi_tinh>Nam</gioi_tinh>
    </sinhvien>
    <sinhvien ma_sv="SV002">
        <ho_ten>Trần Thị Bình</ho_ten>
        <nam_sinh>2003</nam_sinh>
        <lop>CTK45</lop>
        <gioi_tinh>Nữ</gioi_tinh>
    </sinhvien>
    <sinhvien ma_sv="SV003">
        <ho_ten>Lê Văn Cường</ho_ten>
        <nam_sinh>2001</nam_sinh>
        <lop>CTK43</lop>
        <gioi_tinh>Nam</gioi_tinh>
    </sinhvien>
</danhsach_sinhvien>
"""

# Ghi nội dung XML ra file
with open("danhsach_sinhvien.xml", "w", encoding="utf-8") as tep:
    tep.write(noi_dung_xml)

print("Đã tạo file 'danhsach_sinhvien.xml' thành công!")
# Out:
# Đã tạo file 'danhsach_sinhvien.xml' thành công!

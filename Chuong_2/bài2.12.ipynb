# %%
import requests

def doc_bai_post():
    url = "https://jsonplaceholder.typicode.com/posts"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        
        posts = response.json()
        
        print(f"Tổng số bài post: {len(posts)}")
        print("\nDanh sách các bài post:")
        print("=" * 80)
        
        for i, post in enumerate(posts[:10], 1):  # Hiển thị 10 bài đầu
            print(f"Bài {i}:")
            print(f"  UserID: {post['userId']}")
            print(f"  ID: {post['id']}")
            print(f"  Tiêu đề: {post['title']}")
            print(f"  Nội dung: {post['body'][:100]}...")  # Giới hạn nội dung
            print("-" * 80)
            
    except Exception as e:
        print(f"Lỗi khi đọc API: {e}")

doc_bai_post()
# Out:
# Tổng số bài post: 100
#
# Danh sách các bài post:
# ...
# Bài 1:
#   UserID: 1
#   ID: 1
#   Tiêu đề: sunt aut facere repellat provident occaecati excepturi optio reprehenderit
#   Nội dung: quia et suscipit
# suscipit recusandae consequuntur expedita et cum
# reprehenderit molestiae ut ut quas...
# --------------------------------------------------------------------------------
# Bài 2:
#   UserID: 1
#   ID: 2
#   Tiêu đề: qui est esse
#   Nội dung: est rerum tempore vitae
# sequi sint nihil reprehenderit dolor beatae ea dolores neque
# fugiat blanditi...
# --------------------------------------------------------------------------------
# Bài 3:
#   UserID: 1
#   ID: 3
#   Tiêu đề: ea molestias quasi exercitationem repellat qui ipsa sit aut
#   Nội dung: et iusto sed quo iure
# voluptatem occaecati omnis eligendi aut ad
# voluptatem doloribus vel accusantiu...
# --------------------------------------------------------------------------------
# Bài 4:
#   UserID: 1
#   ID: 4
# ...

# %%
class hinhchunhat:
    # khởi tạo hàm (contruction) gồm 2 thuộc tính : chiều dài , chiều rộng
    def __init__(self, dai=0, rong=0):
        self.dai=dai
        self.rong=rong
    # phương thức nhập dữ liệu
    def nhap(self):
        self.dai=float(input("nhập chiều dài: "))
        self.rong=float(input("nhap chiều rộng: "))
        print(f"Chiều dài: {self.dai}")
        print(f"Chiều rộng: {self.rong}")
    # tính chu vi hình chữ nhật
    def chu_vi(self):
        p=(self.dai+self.rong)*2
        print("chu vi là",p)
    # tính diện tích hình chữ nhật
    def dien_tich(self):
        s=self.dai*self.rong
        print("diện tích là", s)
    print("THÔNG TIN HÌNH CHỮ NHAT")
hcn=hinhchunhat()
hcn.nhap()
hcn.chu_vi()
hcn.dien_tich()
# Out:
# THÔNG TIN HÌNH CHỮ NHAT
# Chiều dài: 9.0
# Chiều rộng: 5.0
# chu vi là 28.0
# diện tích là 45.0

# %%
class Stack:
    def __init__(self, max_size=100):
        self.stack = []
        self.max_size = max_size
        self.top = -1

    def __del__(self):
        print("Stack đã bị hủy.")

    def push(self, value):
        if self.isFull():
            print("Stack đầy! Không thể thêm phần tử.")
            return
        self.stack.append(float(value))
        self.top += 1
        print(f"Đã thêm {value} vào stack.")

    def pop(self):
        if self.isEmpty():
            print("Stack trống! Không thể lấy phần tử.")
            return None
        value = self.stack.pop()
        self.top -= 1
        print(f"Đã lấy {value} ra khỏi stack.")
        return value

    def isEmpty(self):
        return self.top == -1

    def isFull(self):
        return self.top == self.max_size - 1

    def count(self):
        return self.top + 1

    def printStack(self):
        if self.isEmpty():
            print("Stack trống.")
        else:
            print("Nội dung stack (từ dưới lên trên):")
            for i in range(self.top + 1):
                print(self.stack[i], end=" ")
            print()


# --- Chương trình chính ---
if __name__ == "__main__":
    n = int(input("Nhập kích thước tối đa của stack: "))
    s = Stack(n)

    while True:
        print("\n1. Thêm phần tử (push)")
        print("2. Lấy phần tử (pop)")
        print("3. Kiểm tra rỗng")
        print("4. Kiểm tra đầy")
        print("5. Đếm số phần tử")
        print("6. In nội dung stack")
        print("7. Thoát")

        chon = input("Chọn thao tác: ")

        if chon == "1":
            value = input("Nhập giá trị cần thêm: ")
            s.push(value)
        elif chon == "2":
            s.pop()
        elif chon == "3":
            if s.isEmpty():
                print("Stack rỗng.")
            else:
                print("Stack không rỗng.")
        elif chon == "4":
            if s.isFull():
                print("Stack đầy.")
            else:
                print("Stack chưa đầy.")
        elif chon == "5":
            print("Số phần tử trong stack:", s.count())
        elif chon == "6":
            s.printStack()
        elif chon == "7":
            print("Kết thúc chương trình.")
            break
        else:
            print("Lựa chọn không hợp lệ.")
# Out:
# Stack đã bị hủy.
#
# 1. Thêm phần tử (push)
# 2. Lấy phần tử (pop)
# 3. Kiểm tra rỗng
# 4. Kiểm tra đầy
# 5. Đếm số phần tử
# 6. In nội dung stack
# 7. Thoát
# Đã thêm 2 vào stack.
#
# 1. Thêm phần tử (push)
# 2. Lấy phần tử (pop)
# 3. Kiểm tra rỗng
# 4. Kiểm tra đầy
# 5. Đếm số phần tử
# 6. In nội dung stack
# 7. Thoát
# Nội dung stack (từ dưới lên trên):
# 2.0
#
# 1. Thêm phần tử (push)
# 2. Lấy phần tử (pop)
# 3. Kiểm tra rỗng
# 4. Kiểm tra đầy
# 5. Đếm số phần tử
# 6. In nội dung stack
# 7. Thoát
# Lựa chọn không hợp lệ.
#
# 1. Thêm phần tử (push)
# 2. Lấy phần tử (pop)
# 3. Kiểm tra rỗng
# 4. Kiểm tra đầy
# 5. Đếm số phần tử
# 6. In nội dung stack
# 7. Thoát
